# %%
import numpy as np
import pandas as pd

# %%
collision_data  = pd.read_csv('datasets/pd_collisions_datasd.csv')
collision_dict = pd.read_csv('datasets/pd_collisions_dictionary_datasd.csv')

# %%
collision_dict
# Out:
#                 Field                                        Description  \
# 0      activityNumber                            Collision report number
# 1        activityDate                             Date/time of collision
# 2                beat                              San Diego Police beat
# 3            StreetNo  Street number of collision location, abstracte...
# 4           StreetDir                    Direction of street in location
# 5          StreetName                                     Name of street
# 6          StreetType                                        Street type
# 7          CrossStDir  Direction of cross street, if collision at int...
# 8         CrossStName          Street name, if collision at intersection
# 9         CrossStType          Street type, if collision at intersection
# 10   violationSection     Violation section for primary collision factor
# 11      violationType        Violation type for primary collision factor
# ...

# %%
collision_data
# Out:
#       report_id            date_time  police_beat  street_no street_dir  \
# 0        170166  2017-01-01 00:01:00          124       8300
# 1        170218  2017-01-01 00:01:00          325       8100
# 2        170101  2017-01-01 00:01:00          322       6400
# 3        170082  2017-01-01 00:01:00          935       5500
# 4        170097  2017-01-01 01:00:00          521       1000
# 5        170220  2017-01-01 01:00:00          524       1000
# 6        170153  2017-01-01 01:18:00          437       2600
# 7        170035  2017-01-01 01:53:00          935       3900
# 8        170044  2017-01-01 01:58:00          115       9100
# 9        170042  2017-01-01 02:00:00          122       1600
# 10       170041  2017-01-01 02:00:00          122        900
# 11       170139  2017-01-01 02:03:00          434          0
# 12       170090  2017-01-01 04:10:00          813       2900
# 13       170073  2017-01-01 04:43:00          242      10000
# ...

# %%
traffic_data = pd.read_csv('datasets/traffic_counts_datasd.csv')
traffic_dict = pd.read_csv('datasets/traffic_counts_dictionary_datasd.csv')

# %%
traffic_dict
# Out:
#               Field                                        Description
# 0       street_name           The vehicles were counted on this street
# 1            limits  The vehicles were counted between these cross ...
# 2  northbound_count           The 24 hour count of northbound vehicles
# 3  southbound_count           The 24 hour count of southbound vehicles
# 4   eastbound_count            The 24 hour count of eastbound vehicles
# 5   westbound_count            The 24 hour count of westbound vehicles
# 6       total_count  The 24 hour total of all directions of vehicle...
# 7        count_date             The vehicles were counted on this date

# %%
traffic_data
# Out:
#                        id     street_name                           limits  \
# 0              01AV018207           01 AV                    A ST - ASH ST
# 1              01AV015210           01 AV                    A ST - ASH ST
# 2              01AV018213           01 AV                    A ST - ASH ST
# 3              01AV088812           01 AV                ASH ST - BEECH ST
# 4              01AV068711           01 AV                      B ST - A ST
# 5              01AV000714           01 AV                      B ST - A ST
# 6              01AV048412           01 AV                      B ST - C ST
# 7              01AV048115           01 AV                      B ST - C ST
# 8              01AV019406           01 AV              BEECH ST - CEDAR ST
# 9              01AV017909           01 AV              BEECH ST - CEDAR ST
# 10             01AV018912           01 AV              BEECH ST - CEDAR ST
# ...
